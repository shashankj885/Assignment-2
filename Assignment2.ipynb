# %% [markdown]
# Ans 1 - Two values of Boolean data types are - True and Flase, Both should start with Capital Word.
#
# Ans 2 - Three types of boolean operators are - and , not, and or.
#
# Ans 3 - 2>5 or 5<5 - False
#         2>5 and 5<5 - False
#         5==5 and 5<5 -False
#         5==5 or 5<5 - True
#         not(5!=6) - False
#         not(5!=5) - True
#
# Ans 4 - False
#         False
#         True
#         False
#         Flase
#         True
#
# Ans 5 - less than (<)
#         greater than (>)
#         equal to (==)
#         not equal to (!=)
#         less than equal to (<=)
#         greater than equal to(>=)
#
# Ans 6 - When we have assign any value to variable use assignment operators by single equal to (=) sign.
#         ex- x = y + z, a += b , a-=b , a *= b , a /= b,
#         while in equal to (relational operator) use double equal to sign(==).
#         x==5
#
#
# Ans 7
# spam = 0
#
# Block -1
#
# if spam == 10:
# print('eggs')
#
# Block -2
#
# if spam > 5:
# print('bacon')
#
# Block -3
#
# else:
# print('ham')
# print('spam')
# print('spam')
#
# Ans 8-
#
# spam=int(input())
#
# if spam==1:
#     print ('Hello')
# if spam==2:
#     print('Howdy')
# if spam > 2 or spam<1:
#     print("Greetings!")
#
# Ans 9-ctrl + C
#
# Ans -10
#
# Break Statement -The break statement teminates the current loop and resumes at the next statement immediately after the end of the loop.
#
# x="strings"
# for u in x:
#     if u=="i":
#         break
#     print(u)
# print("over")
#
# output
#
# s
# t
# r
# over
#
# Continue statement -when continue statement is applied then control jumpas directly to the begging of the loop for next iteration by skipping the execution of the statement inside the body of the loop for current iteration.
#
# x="strings"
# for u in x:
#     if u=="i":
#         continue
#     print(u)
# print("over")
#
# output
#
# s
# t
# r
# n
# g
# s
# over
#
# Ans 11 - In for loop
#         range(10) - signfies that it automatically starts with 0 and by jump of 1 but stricty ends on 9.
#         range(0,10) -signfies that, by the jump of 1 it stricty starts with 0 and ends on 9.
#         range(0,10,1) - signfies that, it stricty starts with 0 and ends on 9 by the jump of 1.
#
# Ans 12 -  for loop-
#
#         range(11)
#         for i in range(1,11):
#              print(i)
#
#            While loop
#
#          i=1
#          while (i<=10):
#               print(i)
#               i=i+1
#
# Ans 13  by pressing "Tab"
